# %% [markdown]
# # Using ephesos to extract light curve features of a population of systems

# %%
from pathlib import Path

from run_population import run_example

output_paths = run_example(Path("population_animations"))
output_paths
