# %%
from pathlib import Path

from run_WASP43 import run_example

output_path = Path("run_WASP43.gif")
time_hours, relative_flux = run_example(output_path)
output_path
# Out:
# Traceback (most recent call last):
#
#   File "/Users/tdaylan/anaconda2/envs/mypython3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-e656278f250d>", line 3, in <module>
#     import ephesos
#
#   File "/Users/tdaylan/Documents/work/git/ephesos/ephesos/__init__.py", line 1, in <module>
#     from .main import *
#
#   File "/Users/tdaylan/Documents/work/git/ephesos/ephesos/main.py", line 5948
#     listnamevarbtotl = dictefes['dictinpt'].keys())
#                                                   ^
# SyntaxError: invalid syntax
